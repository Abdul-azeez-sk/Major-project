# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
df = pd.read_excel('2024_2021_tomato_modal_data.xlsx')

# %%
df
# Out:
#           DDate VarityName CommName  AvgModel
# 0    2021-01-01     Common   Tomato     650.0
# 1    2021-01-02     Common   Tomato     900.0
# 2    2021-01-03     Common   Tomato     750.0
# 3    2021-01-04     Common   Tomato     600.0
# 4    2021-01-05     Common   Tomato     650.0
# ...         ...        ...      ...       ...
# 1420 2024-11-26     Common   Tomato    2900.0
# 1421 2024-11-27     Common   Tomato    2750.0
# 1422 2024-11-28     Common   Tomato    2775.0
# 1423 2024-11-29     Common   Tomato    2600.0
# 1424 2024-11-30     Common   Tomato    2900.0
#
# [1425 rows x 4 columns]

# %%
# Assuming your DataFrame is df
df['DDate'] = pd.to_datetime(df['DDate'])
df = df.sort_values('DDate')  # Important for time series

# Set date as index
df.set_index('DDate', inplace=True)

# Keep only the target column
ts = df['AvgModel']

# %%
ts.plot(figsize=(12, 5), title="Average Model Price Over Time")
plt.xlabel("Date")
plt.ylabel("Price")
plt.grid(True)
plt.show()

# %%
# Fit ARIMA model
model = ARIMA(ts, order=(5, 1, 2))
model_fit = model.fit()

# Summary of model
print(model_fit.summary())
# Out:
# C:\Users\abdul\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\abdul\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\abdul\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
# Split into train/test
train = ts[:-30]
test = ts[-30:]

# Re-fit on train
model = ARIMA(train, order=(5, 1, 2))
model_fit = model.fit()

# Forecast
forecast = model_fit.forecast(steps=30)

# Evaluation
mse = mean_squared_error(test, forecast)
print(f"Mean Squared Error: {mse:.2f}")

# Plot
plt.figure(figsize=(12, 5))
plt.plot(test.index, test, label="Actual")
plt.plot(test.index, forecast, label="Forecast", linestyle='--')
plt.title("ARIMA Forecast vs Actual")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\abdul\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\abdul\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\abdul\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...
